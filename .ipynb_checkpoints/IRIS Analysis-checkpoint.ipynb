# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
# import the libraries 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# import the dataset
df = pd.read_csv("Iris.csv")

# %%
# show first few lines 
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# check for inconsistency in the dataset
# there are no null values, so the data can be processed 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
# remove unnecessary column 
df.drop('Id', axis = 1, inplace = True)

# %%
df.Species = df.Species.astype('category')

# %% [markdown]
# ## Perform some explanatory data analysis with Iris

# %% [markdown]
# The graph shows the relationship between the sepal length and the sepal width.

# %%
sns.set_style('dark')

# %%
f, ax = plt.subplots(figsize = (12, 7))
ax  = sns.scatterplot(x = 'SepalLengthCm', y = 'SepalWidthCm', data = df, hue = 'Species')
ax.set_title('Sepal Length vs Sepal Width')
ax.set_xlabel('Sepal Length (cm)')
ax.set_ylabel('Sepal Width (cm)')
plt.show()

# %%
f, ax = plt.subplots(figsize = (12, 7))
ax  = sns.scatterplot(x = 'PetalLengthCm', y = 'PetalWidthCm', data = df, hue = 'Species')
ax.set_title('Petal Length vs Petal Width')
ax.set_xlabel('Petal Length (cm)')
ax.set_ylabel('Petal Width (cm)')
plt.show()

# %% [markdown]
# As we can see, the petal features obviously provide better cluster division than the sepal features and thus will help making predictions about the species of iris more accurately.

# %% [markdown]
# Let's see how the lengths and widths are distributed.

# %%
ax = df.hist(edgecolor = 'black')
plt.rcParams["figure.figsize"] = (12, 8)
plt.show()

# %% [markdown]
# Let's see how the lenght and width vary according to the species.

# %%
f, axes = plt.subplots(2, 2, figsize = (12, 8))
ax1 = sns.violinplot(x = 'Species', y = 'PetalLengthCm', data = df, ax = axes[0, 0]) 
ax2 = sns.violinplot(x = 'Species', y = 'PetalWidthCm', data = df, ax = axes[0, 1]) 
ax3 = sns.violinplot(x = 'Species', y = 'SepalLengthCm', data = df, ax = axes[1, 0]) 
ax4 = sns.violinplot(x = 'Species', y = 'SepalWidthCm', data = df, ax = axes[1, 1])

# %% [markdown]
# The violinplot shows the distribution and density of each features. The thinner part denotes that there is less density whereas the fatter part conveys higher density

# %% [markdown]
# ## Species Classification

# %% [markdown]
# **Classification**: amples belong to two or more classes and we want to learn from already labeled data how to predict the class of unlabeled data
#
# **Regression**: if the desired output consists of one or more continuous variables, then the task is called regression. An example of a regression problem would be the prediction of the length of a salmon as a function of its age and weight.
